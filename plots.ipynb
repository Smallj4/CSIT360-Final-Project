# %%
import seaborn as sns
import pandas as pd

# %%
data = pd.read_csv("data/soccerdata.csv")
data.describe()
# Out:
#          Unnamed: 0  National_Kit      Club_Kit        Rating       Height  \
# count  17588.000000  17588.000000  17588.000000  17588.000000  17588.00000
# mean    8793.500000      0.746873     21.293325     66.166193    181.10547
# std     5077.362603      3.391840     19.163869      7.083012      6.67516
# min        0.000000      0.000000      0.000000     45.000000    155.00000
# 25%     4396.750000      0.000000      9.000000     62.000000    176.00000
# 50%     8793.500000      0.000000     18.000000     66.000000    181.00000
# 75%    13190.250000      0.000000     27.000000     71.000000    186.00000
# max    17587.000000     36.000000     99.000000     94.000000    207.00000
#
#              Weight           Age     Weak_foot   Skill_Moves  Ball_Control  \
# count  17588.000000  17588.000000  17588.000000  17588.000000  17588.000000
# mean      75.253355     25.460314      2.934103      2.303161     57.972766
# ...

# %%
top_two = data["Rating"].nlargest(2)
    
print(top_two)
# Out:
# 0    94
# 1    93
# Name: Rating, dtype: int64

# %%
sns.scatterplot(data = data, x="Age", y="Name")
# Out:
# <Axes: xlabel='Age', ylabel='Name'>

# %%
sns.scatterplot(x="Name", y = "Age", hue = "Penalties", data = data)
# Out:
# <Axes: xlabel='Name', ylabel='Age'>
